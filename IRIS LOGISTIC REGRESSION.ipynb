# %% [markdown]
# # MULTINOMIAL REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('Iris.csv')
data.head(1)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa

# %%
X=data.drop(['Id','Species'],axis=1)
y=data['Species']
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=5)

# %%
clf=LogisticRegression(random_state=0,multi_class='multinomial',solver='newton-cg')

# %%
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 60             5.0           2.0            3.5           1.0
# 147            6.5           3.0            5.2           2.0
# 104            6.5           3.0            5.8           2.2
# 52             6.9           3.1            4.9           1.5
# 22             4.6           3.6            1.0           0.2
# 75             6.6           3.0            4.4           1.4
# 37             4.9           3.1            1.5           0.1
# 77             6.7           3.0            5.0           1.7
# 145            6.7           3.0            5.2           2.3
# 64             5.6           2.9            3.6           1.3
# 136            6.3           3.4            5.6           2.4
# 94             5.6           2.7            4.2           1.3
# 127            6.1           3.0            4.9           1.8
# 87             6.3           2.3            4.4           1.3
# 92             5.8           2.6            4.0           1.2
# 95             5.7           3.0            4.2           1.2
# 139            6.9           3.1            5.4           2.1
# 76             6.8           2.8            4.8           1.4
# 32             5.2           4.1            1.5           0.1
# 101            5.8           2.7            5.1           1.9
# 13             4.3           3.0            1.1           0.1
# 24             4.8           3.4            1.9           0.2
# 59             5.2           2.7            3.9           1.4
# 45             4.8           3.0            1.4           0.3
# 34             4.9           3.1            1.5           0.1
# 131            7.9           3.8            6.4           2.0
# 93             5.0           2.3            3.3           1.0
# 47             4.6           3.2            1.4           0.2
# 116            6.5           3.0            5.5           1.8
# 9              4.9           3.1            1.5           0.1
# ..             ...           ...            ...           ...
# 140            6.7           3.1            5.6           2.4
# 51             6.4           3.2            4.5           1.5
# 105            7.6           3.0            6.6           2.1
# 36             5.5           3.5            1.3           0.2
# 110            6.5           3.2            5.1           2.0
# 4              5.0           3.6            1.4           0.2
# 141            6.9           3.1            5.1           2.3
# 0              5.1           3.5            1.4           0.2
# 58             6.6           2.9            4.6           1.3
# 5              5.4           3.9            1.7           0.4
# 103            6.3           2.9            5.6           1.8
# 129            7.2           3.0            5.8           1.6
# 41             4.5           2.3            1.3           0.3
# 106            4.9           2.5            4.5           1.7
# 121            5.6           2.8            4.9           2.0
# 125            7.2           3.2            6.0           1.8
# 86             6.7           3.1            4.7           1.5
# 30             4.8           3.1            1.6           0.2
# 65             6.7           3.1            4.4           1.4
# 44             5.1           3.8            1.9           0.4
# 27             5.2           3.5            1.5           0.2
# 80             5.5           2.4            3.8           1.1
# 113            5.7           2.5            5.0           2.0
# 7              5.0           3.4            1.5           0.2
# 112            6.8           3.0            5.5           2.1
# 8              4.4           2.9            1.4           0.2
# 73             6.1           2.8            4.7           1.2
# 144            6.7           3.3            5.7           2.5
# 118            7.7           2.6            6.9           2.3
# 99             5.7           2.8            4.1           1.3
#
# [90 rows x 4 columns]

# %%
y_train
# Out:
# 60     Iris-versicolor
# 147     Iris-virginica
# 104     Iris-virginica
# 52     Iris-versicolor
# 22         Iris-setosa
# 75     Iris-versicolor
# 37         Iris-setosa
# 77     Iris-versicolor
# 145     Iris-virginica
# 64     Iris-versicolor
# 136     Iris-virginica
# 94     Iris-versicolor
# 127     Iris-virginica
# 87     Iris-versicolor
# 92     Iris-versicolor
# 95     Iris-versicolor
# 139     Iris-virginica
# 76     Iris-versicolor
# 32         Iris-setosa
# 101     Iris-virginica
# 13         Iris-setosa
# 24         Iris-setosa
# 59     Iris-versicolor
# 45         Iris-setosa
# 34         Iris-setosa
# 131     Iris-virginica
# 93     Iris-versicolor
# 47         Iris-setosa
# 116     Iris-virginica
# 9          Iris-setosa
#             ...
# 140     Iris-virginica
# 51     Iris-versicolor
# 105     Iris-virginica
# 36         Iris-setosa
# 110     Iris-virginica
# 4          Iris-setosa
# 141     Iris-virginica
# 0          Iris-setosa
# 58     Iris-versicolor
# 5          Iris-setosa
# 103     Iris-virginica
# 129     Iris-virginica
# 41         Iris-setosa
# 106     Iris-virginica
# 121     Iris-virginica
# 125     Iris-virginica
# 86     Iris-versicolor
# 30         Iris-setosa
# 65     Iris-versicolor
# 44         Iris-setosa
# 27         Iris-setosa
# 80     Iris-versicolor
# 113     Iris-virginica
# 7          Iris-setosa
# 112     Iris-virginica
# 8          Iris-setosa
# 73     Iris-versicolor
# 144     Iris-virginica
# 118     Iris-virginica
# 99     Iris-versicolor
# Name: Species, Length: 90, dtype: object

# %%
model=clf.fit(X_train,y_train)

# %%
new_observation=[[6.5,3.0,5.8,2.2]]

# %%
model.predict(new_observation)
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
model.predict_proba(new_observation)
# Out:
# array([[2.23211304e-05, 3.02454190e-02, 9.69732260e-01]])

# %%
new_observation=[[4.6,3.6,1.0,0.2]]

# %%
model.predict(new_observation)
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
model.predict_proba(new_observation)
# Out:
# array([[9.93883251e-01, 6.11670752e-03, 4.17727902e-08]])
