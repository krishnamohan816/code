# %% [markdown]
# # Regression algorithm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import preprocessing

# %%
data = pd.read_csv('advertise.csv')
data.head(25)
# Out:
#      sno     TV  Radio  Newspaper  Sales
# 0    NaN    NaN    NaN        NaN    NaN
# 1    1.0  230.1   37.8       69.2   22.1
# 2    NaN    NaN    NaN        NaN    NaN
# 3    2.0   44.5   39.3       45.1   10.4
# 4    NaN    NaN    NaN        NaN    NaN
# 5    3.0   17.2   45.9       69.3    9.3
# 6    NaN    NaN    NaN        NaN    NaN
# 7    4.0  151.5   41.3       58.5   18.5
# 8    NaN    NaN    NaN        NaN    NaN
# 9    5.0  180.8   10.8       58.4   12.9
# 10   NaN    NaN    NaN        NaN    NaN
# 11   6.0    8.7   48.9       75.0    7.2
# 12   NaN    NaN    NaN        NaN    NaN
# 13   7.0   57.5   32.8       23.5   11.8
# 14   NaN    NaN    NaN        NaN    NaN
# 15   8.0  120.2   19.6       11.6   13.2
# 16   NaN    NaN    NaN        NaN    NaN
# 17   9.0    8.6    2.1        1.0    4.8
# 18   NaN    NaN    NaN        NaN    NaN
# 19  10.0  199.8    2.6       21.2   10.6
# 20   NaN    NaN    NaN        NaN    NaN
# 21  11.0   66.1    5.8       24.2    8.6
# 22   NaN    NaN    NaN        NaN    NaN
# 23  12.0  214.7   24.0        4.0   17.4
# 24   NaN    NaN    NaN        NaN    NaN

# %%
data.dropna(inplace=True)

# %%
data.columns
# Out:
# Index(['sno', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import datasets, linear_model
lm= linear_model.LinearRegression()
#lm=LogisticRegression()
X = data.drop(['sno', 'Sales'],axis=1)

y = data['Sales']
# print(X.head())
print(X.shape)
# print(y.head())
print(y.shape)
# Out:
# (200, 3)
# (200,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
y_train.head(1)
# Out:
# 301    16.1
# Name: Sales, dtype: float64

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([0.04481761, 0.1802955 , 0.00117012])

# %%
lm.intercept_
# Out:
# 3.2286202507351707

# %%
lm.score(X_test,y_test)
# Out:
# 0.9146356919015229

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1.2958083354169347
# MSE: 2.544635197264287
# RMSE: 1.5951912729401097

# %%
lm.fit(X_test, y_test)

# make a prediction for an example of an out-of-sample observation
lm.predict([[200,30,59]])
# Out:
# array([17.70404821])

# %%
X_test
# Out:
#         TV  Radio  Newspaper
# 75    74.7   49.4       45.7
# 219  255.4   26.9        5.5
# 63   112.9   17.4       38.6
# 179  109.8   47.8       51.4
# 133   31.5   24.6        2.2
# 239   19.4   16.0       22.3
# 109  262.7   28.8       15.9
# 149  213.4   24.6       13.1
# 291  140.3    1.9        9.0
# 285  220.5   33.2       37.9
# 297   38.0   40.3       11.9
# 225  175.7   15.4        2.4
# 349  222.4    3.4       13.1
# 111  198.9   49.4       60.0
# 283  193.7   35.4       75.6
# 299   44.7   25.8       20.6
# 51   262.9    3.5       19.5
# 69    95.7    1.4        7.4
# 341   50.0   11.6       18.4
# 79   228.0   37.7       32.0
# 345   19.6   20.1       17.0
# 307  171.3   39.7       37.7
# 351  276.9   48.9       41.8
# 123  261.3   42.7       54.7
# 131   69.0    9.3        0.9
# 101  199.8    3.1       34.6
# 85   293.6   27.7        1.8
# 259   59.6   12.0       43.1
# 359  165.6   10.0       17.6
# 5     17.2   45.9       69.3
# ..     ...    ...        ...
# 3     44.5   39.3       45.1
# 87   206.9    8.4       26.4
# 205  280.2   10.1       21.4
# 329  117.2   14.7        5.4
# 19   199.8    2.6       21.2
# 311    4.1   11.6        5.7
# 73   266.9   43.8        5.0
# 381   39.5   41.1        5.8
# 67   265.6   20.0        0.3
# 91   175.1   22.5       31.5
# 171  193.2   18.4       65.7
# 367  287.6   43.0       71.8
# 255   80.2    0.0        9.2
# 107  182.6   46.2       58.7
# 201  222.4    4.3       49.8
# 187  250.9   36.5       72.3
# 309  187.8   21.1        9.5
# 229   78.2   46.8       34.5
# 237  125.7   36.9       79.2
# 129  131.1   42.8       28.9
# 331  234.5    3.4       84.8
# 49    62.3   12.6       18.3
# 377  286.0   13.9        3.7
# 235   76.4    0.8       14.8
# 27    97.5    7.6        7.2
# 105  216.4   41.7       39.6
# 323   85.7   35.8       49.3
# 295  243.2   49.0       44.3
# 113    7.3   28.1       41.4
# 399  232.1    8.6        8.7
#
# [80 rows x 3 columns]

# %%
y_test
# Out:
# 75     14.7
# 219    19.8
# 63     11.9
# 179    16.7
# 133     9.5
# 239     6.6
# 109    20.2
# 149    17.0
# 291    10.3
# 285    20.1
# 297    10.9
# 225    14.1
# 349    11.5
# 111    23.7
# 283    19.2
# 299    10.1
# 51     12.0
# 69      9.5
# 341     8.4
# 79     21.5
# 345     7.6
# 307    19.0
# 351    27.0
# 123    24.2
# 131     9.3
# 101    11.4
# 85     20.7
# 259     9.7
# 359    12.6
# 5       9.3
#        ...
# 3      10.4
# 87     12.9
# 205    14.8
# 329    11.9
# 19     10.6
# 311     3.2
# 73     25.4
# 381    10.8
# 67     17.4
# 91     14.9
# 171    15.2
# 367    26.2
# 255     8.8
# 107    21.2
# 201    11.7
# 187    22.2
# 309    15.6
# 229    14.6
# 237    15.9
# 129    18.0
# 331    11.9
# 49      9.7
# 377    15.9
# 235     9.4
# 27      9.7
# 105    22.6
# 323    13.3
# 295    25.4
# 113     5.5
# 399    13.4
# Name: Sales, Length: 80, dtype: float64

# %%
data.columns
# Out:
# Index(['sno', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
import pandas as pd
data['Sales'].corr(data['Radio']),data['Sales'].corr(data['TV']),data['Sales'].corr(data['Newspaper'])
# Out:
# (0.5762225745710551, 0.7822244248616061, 0.22829902637616528)

# %%
lm.coef_
# Out:
# array([ 0.04707532,  0.20046025, -0.00476792])
